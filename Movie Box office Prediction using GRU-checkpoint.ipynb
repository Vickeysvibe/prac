# %%
import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split 
from keras.layers import Input, Embedding, GRU, Dense 
from keras.models import Model 
from keras.callbacks import EarlyStopping

# %%
df = pd.read_csv(r"C:\Users\ARAVINTH1\Downloads\bollywood_box_clean.csv") 
df
# Out:
#                              movie_name  movie_opening  movie_weekend  \
# 0                        Angrezi Medium           4.03           9.03
# 1                              Baaghi 3          17.50          53.83
# 2                               Thappad           3.07          14.66
# 3           Shubh Mangal Zyada Saavdhan           9.55          32.66
# 4    Bhoot: Part One - The Haunted Ship           5.10          16.36
# ..                                  ...            ...            ...
# 125                              Bhoomi           2.25           7.48
# 126                      Haseena Parkar           1.87           6.10
# 127                     Lucknow Central           2.04           8.42
# 128                              Simran           2.77          10.65
# 129                         Poster Boys           1.75           7.25
#
#      movie_firstweek  movie_total  movie_total_worldwide          movie_genre  \
# ...

# %%
x = df[["movie_opening","movie_weekend","movie_firstweek"]] 
y = df["movie_total_worldwide"] 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
input_shape = (x_train.shape[1], 1) 
input_layer = Input(shape=input_shape) 
gru_layer = GRU(64, return_sequences=True, dropout=0.2, recurrent_dropout=0.2)(input_layer) 
gru_layer = GRU(32, return_sequences=True, dropout=0.2, recurrent_dropout=0.2)(gru_layer) 
gru_layer = GRU(16, dropout=0.2, recurrent_dropout=0.2)(gru_layer) 
output_layer = Dense(1, activation='linear')(gru_layer) 
model = Model(input_layer, output_layer) 
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5) 
model.fit(x_train, y_train, epochs=100, batch_size=32, validation_data=(x_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 232ms/step - loss: 30179.0000 - mean_absolute_error: 109.1055 - val_loss: 34691.7148 - val_mean_absolute_error: 122.2092
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 29231.9297 - mean_absolute_error: 107.0121 - val_loss: 34587.0234 - val_mean_absolute_error: 121.9522
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 25731.1484 - mean_absolute_error: 101.3271 - val_loss: 34494.9414 - val_mean_absolute_error: 121.7276
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 28533.3613 - mean_absolute_error: 109.3394 - val_loss: 34410.5000 - val_mean_absolute_error: 121.5246
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 23252.9570 - mean_absolute_error: 95.5138 - val_loss: 34335.1016 - val_mean_absolute_error: 121.3457
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 25832.5039 - mean_absolute_error: 102.7788 - val_loss: 34263.6523 - val_mean_absolute_error: 121.1796
# Epoch 7/100
# ...

# %%
test_loss = model.evaluate(x_test, y_test) 
print(f'Test loss: {test_loss}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 32433.7148 - mean_absolute_error: 117.6355
# Test loss: [32433.71484375, 117.63550567626953]

# %%
import numpy as np

y_pred = model.predict(np.array([[171.50, 123, 234]]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step

# %%
print(y_pred)
# Out:
# [[10.423552]]
